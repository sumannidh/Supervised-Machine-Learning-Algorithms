# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df= pd.read_csv(r"C:\Users\lenovo\Downloads\homeprices.csv")
# type(df)
print(df)
#df= df.rename(columns{year:year, per capita income : income})
#df.columns= ['year', 'income']
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.ylabel('price')
plt.xlabel('area')
plt.scatter(df.area,df.price)
plt.plot(df.area, reg.predict(df[['area']]),color='red')

# %%
reg= linear_model.LinearRegression()
reg.fit(df[['area']],df.price)## fit implies training the dataset on the given model
# Out:
# LinearRegression()

# %%
reg.predict([[3300]]) ### input should be a 2D array because linear regression requires input to be 2d array incase of multiple features.
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
reg.coef_  ##m value
# Out:
# array([135.78767123])

# %%
reg.intercept_  ##b value
# Out:
# 180616.43835616432

# %%
df_2= pd.read_csv(r"C:\Users\lenovo\Downloads\areas.csv")
df_2.head(5)
# Out:
#    area
# 0  1000
# 1  1500
# 2  2300
# 3  3540
# 4  4120

# %%
reg.predict(df_2)
# Out:
# array([ 316404.10958904,  384297.94520548,  492928.08219178,
#         661304.79452055,  740061.64383562,  799808.21917808,
#         926090.75342466,  650441.78082192,  825607.87671233,
#         492928.08219178, 1402705.47945205, 1348390.4109589 ,
#        1144708.90410959])

# %%
df_2['prices']= reg.predict(df_2)  ## add the predicted column into the dataframe

# %%
df_2.to_csv(r"C:\Users\lenovo\Downloads\predicted.txt")
